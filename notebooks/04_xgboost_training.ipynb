# %% [markdown]
# # 04 - Supervised XGBoost Training with Temporal Splitting
# Model fitting with strict chronological validation and PR-AUC optimization.

# %%
from src.cryptotrace.models.classical.xgboost_model import CryptoXGBoostClassifier
model = CryptoXGBoostClassifier.load('../models/xgboost/xgboost_model.pkl')
print("Model successfully loaded")
