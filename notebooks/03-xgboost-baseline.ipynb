# %% [markdown]
# # 03 - XGBoost Baseline & Temporal Benchmark
# Supervised gradient boosting training with PR-AUC evaluation and class imbalance weighting.

# %%
from cryptotrace.models.xgboost_model import CryptoXGBoostClassifier
import pandas as pd

model = CryptoXGBoostClassifier.load('../models/xgboost/xgboost_model.pkl')
print("Model loaded successfully")
