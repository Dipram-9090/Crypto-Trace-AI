# %% [markdown]
# # 06 - Heterogeneous Multi-Layer Graph Construction
# Constructing multi-relational graphs across Transaction, Wallet, IP, ASN, and Country entities.

# %%
from src.cryptotrace.graph.builder import ForensicGraphBuilder
import pandas as pd

df = pd.read_csv('../data/synthetic/transactions.csv')
builder = ForensicGraphBuilder()
G = builder.build_from_dataframe(df)
print(f"Nodes: {G.number_of_nodes()}, Edges: {G.number_of_edges()}")
