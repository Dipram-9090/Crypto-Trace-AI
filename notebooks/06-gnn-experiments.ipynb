# %% [markdown]
# # 06 - Inductive GraphSAGE GNN Experiments
# Deep graph representation learning and inductive node classification across transaction neighborhoods.

# %%
from cryptotrace.models.graphsage import CryptoGraphSAGE
model = CryptoGraphSAGE.load('../models/graphsage/graphsage.pt')
print("GraphSAGE model loaded")
