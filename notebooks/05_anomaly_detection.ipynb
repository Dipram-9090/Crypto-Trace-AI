# %% [markdown]
# # 05 - Behavioral Anomaly Detection & Peeling Discovery
# Unsupervised Isolation Forest training and anomalous cluster analysis.

# %%
from src.cryptotrace.models.anomaly.isolation_forest import CryptoIsolationForest
model = CryptoIsolationForest.load('../models/isolation_forest/isolation_forest.pkl')
print("Isolation Forest loaded")
