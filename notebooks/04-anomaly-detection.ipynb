# %% [markdown]
# # 04 - Behavioral Anomaly Detection with Isolation Forest
# Detecting out-of-distribution structural patterns and peeling anomalies without ground truth labels.

# %%
from cryptotrace.models.isolation_forest import CryptoIsolationForest
model = CryptoIsolationForest.load('../models/isolation_forest/isolation_forest.pkl')
print("Isolation Forest loaded")
