# %% [markdown]
# # 03 - Longitudinal Wallet Analysis & IP Infrastructure Hopping
# Longitudinal analysis of wallet counterparty interactions and infrastructure colocation.

# %%
from src.cryptotrace.storage.duckdb_engine import DuckDBQueryEngine
import pandas as pd

df = pd.read_csv('../data/processed/features.csv')
engine = DuckDBQueryEngine()
engine.register_dataframe('transactions', df)
summary = engine.get_wallet_summary('transactions')
summary.head()
