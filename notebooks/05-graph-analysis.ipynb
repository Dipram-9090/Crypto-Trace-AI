# %% [markdown]
# # 05 - Heterogeneous Graph Construction & Centrality Analytics
# Constructing multi-relational graphs relating Wallets, Transactions, Observed IPs, and ASNs.

# %%
from cryptotrace.graph.builder import ForensicGraphBuilder
import pandas as pd

df = pd.read_csv('../data/synthetic/transactions.csv')
builder = ForensicGraphBuilder()
G = builder.build_from_dataframe(df)
print(f"Nodes: {G.number_of_nodes()}, Edges: {G.number_of_edges()}")
