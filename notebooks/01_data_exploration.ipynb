# %% [markdown]
# # 01 - Multi-Modal Blockchain & Network Data Exploration
# Exploratory analysis of Bitcoin blockchain transaction graphs and observed P2P network telemetry.

# %%
import pandas as pd
from src.cryptotrace.storage.parquet_io import read_parquet

df = read_parquet('../data/synthetic/transactions.parquet')
print("Loaded Transactions:", df.shape)
df.head()
