# %% [markdown]
# # 02 - Feature Engineering & Temporal Dynamics
# Extracting anti-leakage temporal rolling velocity, fan-out ratios, and IP colocation features.

# %%
import pandas as pd
from cryptotrace.features.temporal import TemporalTracker

df_feats = pd.read_csv('../data/processed/features.csv')
print("Engineered Features:", df_feats.shape)
df_feats.describe()
