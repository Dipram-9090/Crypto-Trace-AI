# %% [markdown]
# # 02 - Transaction Structural & Temporal Features
# Feature extraction on fan-out, peeling indicators, Shannon entropy, and rolling temporal velocity.

# %%
from src.cryptotrace.features.builder import FeatureBuilder
import pandas as pd

df = pd.read_csv('../data/synthetic/transactions.csv')
builder = FeatureBuilder()
feats = builder.build_features(df)
print("Engineered Feature Shape:", feats.shape)
