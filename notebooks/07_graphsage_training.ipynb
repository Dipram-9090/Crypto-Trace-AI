# %% [markdown]
# # 07 - Inductive GraphSAGE GNN Training & Embedding
# Deep graph representation learning across multi-hop transaction neighborhoods.

# %%
from src.cryptotrace.models.graph_ml.graphsage import CryptoGraphSAGE
model = CryptoGraphSAGE.load('../models/graphsage/graphsage.pt')
print("GraphSAGE model successfully loaded")
