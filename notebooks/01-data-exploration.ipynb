# %% [markdown]
# # 01 - Data Exploration & Canonical Schema Analysis
# Exploratory analysis of Bitcoin blockchain and network metadata across CSV, JSON, and XML sources.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('../data/synthetic/transactions.csv')
print(f"Total transactions: {len(df)}")
df.head()
